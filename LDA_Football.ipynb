# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Pavan Krovi\\OneDrive\\Desktop\\advance stst'

# %%
import os
import sys
print ("Current Working Directory", os.getcwd())
path = "C:/Users/Pavan Krovi/OneDrive/Desktop/advance stst"
os.chdir(path)
print ("Current Working Directory", os.getcwd())
# Out:
# Current Working Directory C:\Users\Pavan Krovi\OneDrive\Desktop\advance stst
# Current Working Directory C:\Users\Pavan Krovi\OneDrive\Desktop\advance stst

# %%
df = pd.read_csv('Football_Scholarship.csv')
df.head()
# Out:
#    Academic_Score  Score_on_Plays_Made  Missed_Play_Score Injury_Propensity  \
# 0             7.0                 0.27               0.36              High
# 1             6.3                 0.30               0.34               Low
# 2             8.1                 0.28               0.40          Moderate
# 3             7.2                 0.23               0.32          Moderate
# 4             7.2                 0.23               0.32          Moderate
#
#   School_Type  School_Score  Overall_Score   Region Scholarship
# 0           A          0.45            8.8  Eastern     Partial
# 1           C          0.49            9.5  Eastern     Partial
# 2           C          0.44           10.1  Eastern     Partial
# 3           C          0.40            9.9  Eastern     Partial
# 4           C          0.40            9.9  Eastern     Partial

# %%
df.dtypes
# Out:
# Academic_Score         float64
# Score_on_Plays_Made    float64
# Missed_Play_Score      float64
# Injury_Propensity       object
# School_Type             object
# School_Score           float64
# Overall_Score          float64
# Region                  object
# Scholarship             object
# dtype: object

# %%
print('Number of rows:',df.shape[0],'\nNumber of columns:',df.shape[1])
# Out:
# Number of rows: 6215
# Number of columns: 9

# %%
print(df.info(),'\n')
print(df.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6215 entries, 0 to 6214
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Academic_Score       6215 non-null   float64
#  1   Score_on_Plays_Made  6215 non-null   float64
#  2   Missed_Play_Score    6215 non-null   float64
#  3   Injury_Propensity    6215 non-null   object
#  4   School_Type          6215 non-null   object
#  5   School_Score         6215 non-null   float64
#  6   Overall_Score        6215 non-null   float64
#  7   Region               6215 non-null   object
#  8   Scholarship          6215 non-null   object
# dtypes: float64(5), object(4)
# memory usage: 437.1+ KB
# None
#
# Academic_Score         float64
# Score_on_Plays_Made    float64
# Missed_Play_Score      float64
# Injury_Propensity       object
# School_Type             object
# School_Score           float64
# Overall_Score          float64
# ...

# %%
dups = df.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))
print(df.shape)
# Out:
# Number of duplicate rows = 947
# (6215, 9)

# %%
df.drop_duplicates(inplace=True)

# %%
dups = df.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))
print(df.shape)
# Out:
# Number of duplicate rows = 0
# (5268, 9)

# %%
df.isna().sum()
# Out:
# Academic_Score         0
# Score_on_Plays_Made    0
# Missed_Play_Score      0
# Injury_Propensity      0
# School_Type            0
# School_Score           0
# Overall_Score          0
# Region                 0
# Scholarship            0
# dtype: int64

# %%
df.iloc[:,0:8].describe()
# Out:
#        Academic_Score  Score_on_Plays_Made  Missed_Play_Score  School_Score  \
# count     5268.000000          5268.000000        5268.000000   5268.000000
# mean         7.205363             0.337905           0.320306      0.531380
# std          1.299212             0.161308           0.146286      0.146938
# min          3.800000             0.080000           0.000000      0.220000
# 25%          6.400000             0.230000           0.250000      0.430000
# 50%          6.900000             0.290000           0.310000      0.510000
# 75%          7.700000             0.400000           0.400000      0.600000
# max         15.900000             1.330000           1.660000      1.980000
#
#        Overall_Score
# count    5268.000000
# mean       10.502904
# std         1.169325
# min         8.000000
# 25%         9.500000
# 50%        10.300000
# 75%        11.300000
# max        14.900000

# %%
for feature in df.columns: 
    if df[feature].dtype == 'object': 
        print(feature)
        print(df[feature].value_counts())
        print('\n')
# Out:
# Injury_Propensity
# Low         2323
# Normal      1162
# Moderate     893
# High         890
# Name: Injury_Propensity, dtype: int64
#
#
# School_Type
# C    2906
# B    1446
# D     786
# A     130
# Name: School_Type, dtype: int64
#
#
# Region
# Eastern     2403
# Western     1457
# Southern    1408
# Name: Region, dtype: int64
#
#
# Scholarship
# Partial    3337
# Full       1931
# Name: Scholarship, dtype: int64

# %%
df.describe()
# Out:
#        Academic_Score  Score_on_Plays_Made  Missed_Play_Score  School_Score  \
# count     5268.000000          5268.000000        5268.000000   5268.000000
# mean         7.205363             0.337905           0.320306      0.531380
# std          1.299212             0.161308           0.146286      0.146938
# min          3.800000             0.080000           0.000000      0.220000
# 25%          6.400000             0.230000           0.250000      0.430000
# 50%          6.900000             0.290000           0.310000      0.510000
# 75%          7.700000             0.400000           0.400000      0.600000
# max         15.900000             1.330000           1.660000      1.980000
#
#        Overall_Score
# count    5268.000000
# mean       10.502904
# std         1.169325
# min         8.000000
# 25%         9.500000
# 50%        10.300000
# 75%        11.300000
# max        14.900000

# %%
cat=[]
num=[]
for i in df.columns:
    if df[i].dtype=="object":
        cat.append(i)
    else:
        num.append(i)
print(cat) 
print(num)
# Out:
# ['Injury_Propensity', 'School_Type', 'Region', 'Scholarship']
# ['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score', 'School_Score', 'Overall_Score']

# %% [markdown]
# # # Box Plots

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 19,12

# %%
f,a =  plt.subplots(2,2)

plot_00 = sns.boxplot(df['Score_on_Plays_Made'],ax=a[0][0]);
a[0][0].set_title('Score_on_Plays_Made Boxplot')
plot_01 = sns.boxplot(df['Missed_Play_Score'],ax=a[0][1]);
a[0][1].set_title('Missed_Play_Score Boxplot')



plot_10 = sns.boxplot(df['Academic_Score'],ax=a[1][0]);
a[1][0].set_title('Academic_Score Boxplot')
plot_11 = sns.boxplot(df['School_Score'],ax=a[1][1]);
a[1][1].set_title('School_Score Boxplot');
# Out:
# C:\Users\Pavan Krovi\anaconda3_new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Pavan Krovi\anaconda3_new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Pavan Krovi\anaconda3_new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
plt.figure(figsize=(15,4))
sns.boxplot(df['Overall_Score'])
# Out:
# C:\Users\Pavan Krovi\anaconda3_new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Overall_Score'>

# %%
cols = ['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score']
for i in cols:
    sns.boxplot(df[i],whis=1.5)
    plt.grid()
    plt.show();
# Out:
# C:\Users\Pavan Krovi\anaconda3_new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Pavan Krovi\anaconda3_new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Pavan Krovi\anaconda3_new\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
df
# Out:
#       Academic_Score  Score_on_Plays_Made  Missed_Play_Score  \
# 0                7.0                0.270               0.36
# 1                6.3                0.300               0.34
# 2                8.1                0.280               0.40
# 3                7.2                0.230               0.32
# 6                6.2                0.320               0.16
# ...              ...                  ...                ...
# 6209             6.3                0.510               0.13
# 6210             6.8                0.620               0.08
# 6211             6.2                0.600               0.08
# 6212             5.9                0.550               0.10
# 6214             5.9                0.645               0.12
#
#      Injury_Propensity School_Type  School_Score  Overall_Score   Region  \
# 0                 High           A          0.45            8.8  Eastern
# 1                  Low           C          0.49            9.5  Eastern
# ...

# %%
df.Scholarship = df.Scholarship.astype('object')
df1 = df.select_dtypes(exclude='object')
df2 = df1.select_dtypes(exclude='bool')
df5 = df.select_dtypes(exclude='int64')
df6 = df5.select_dtypes(exclude='float64')
df6
# Out:
#      Injury_Propensity School_Type   Region Scholarship
# 0                 High           A  Eastern     Partial
# 1                  Low           C  Eastern     Partial
# 2             Moderate           C  Eastern     Partial
# 3             Moderate           C  Eastern     Partial
# 6             Moderate           C  Eastern        Full
# ...                ...         ...      ...         ...
# 6209               Low           C  Eastern        Full
# 6210               Low           C  Eastern        Full
# 6211               Low           C  Western        Full
# 6212               Low           C  Eastern        Full
# 6214               Low           C  Western        Full
#
# [5268 rows x 4 columns]

# %%
df2
# Out:
#       Academic_Score  Score_on_Plays_Made  Missed_Play_Score  School_Score  \
# 0                7.0                0.270               0.36          0.45
# 1                6.3                0.300               0.34          0.49
# 2                8.1                0.280               0.40          0.44
# 3                7.2                0.230               0.32          0.40
# 6                6.2                0.320               0.16          0.47
# ...              ...                  ...                ...           ...
# 6209             6.3                0.510               0.13          0.75
# 6210             6.8                0.620               0.08          0.82
# 6211             6.2                0.600               0.08          0.58
# 6212             5.9                0.550               0.10          0.76
# 6214             5.9                0.645               0.12          0.71
#
#       Overall_Score
# 0               8.8
# 1               9.5
# ...

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Academic_Score         1.30
# Score_on_Plays_Made    0.17
# Missed_Play_Score      0.15
# School_Score           0.17
# Overall_Score          1.80
# dtype: float64

# %%
np.where((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR)))
# Out:
# (array([  16,   74,   76, ..., 5259, 5260, 5262], dtype=int64),
#  array([8, 2, 2, ..., 8, 8, 8], dtype=int64))

# %%
df3_out = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)] # rows without outliers
df3_out.shape
# Out:
# (4390, 9)

# %%
boston_df4 = df2.copy()

# Replace every outlier on the lower side by the lower whisker
for i, j in zip(np.where(boston_df4 < Q1 - 1.5 * IQR)[0], np.where(boston_df4 < Q1 - 1.5 * IQR)[1]): 
    
    whisker  = Q1 - 1.5 * IQR
    boston_df4.iloc[i,j] = whisker[j]
    
    
#Replace every outlier on the upper side by the upper whisker    
for i, j in zip(np.where(boston_df4 > Q3 + 1.5 * IQR)[0], np.where(boston_df4 > Q3 + 1.5 * IQR)[1]):
    
    whisker  = Q3 + 1.5 * IQR
    boston_df4.iloc[i,j] = whisker[j]

# %%
df = pd.merge(df6, boston_df4, left_index=True, right_index=True)
df
# Out:
#      Injury_Propensity School_Type   Region Scholarship  Academic_Score  \
# 0                 High           A  Eastern     Partial             7.0
# 1                  Low           C  Eastern     Partial             6.3
# 2             Moderate           C  Eastern     Partial             8.1
# 3             Moderate           C  Eastern     Partial             7.2
# 6             Moderate           C  Eastern        Full             6.2
# ...                ...         ...      ...         ...             ...
# 6209               Low           C  Eastern        Full             6.3
# 6210               Low           C  Eastern        Full             6.8
# 6211               Low           C  Western        Full             6.2
# 6212               Low           C  Eastern        Full             5.9
# 6214               Low           C  Western        Full             5.9
#
#       Score_on_Plays_Made  Missed_Play_Score  School_Score  Overall_Score
# ...

# %%
df.Scholarship = df.Scholarship.astype('object')
df.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #outlier treatment done using IQE there are few outliers in missed_play_score and school_score
# columns that are still there but we consider as it is not far away from our upper and lower whiskers.

# %%
df
# Out:
#      Injury_Propensity School_Type   Region Scholarship  Academic_Score  \
# 0                 High           A  Eastern     Partial             7.0
# 1                  Low           C  Eastern     Partial             6.3
# 2             Moderate           C  Eastern     Partial             8.1
# 3             Moderate           C  Eastern     Partial             7.2
# 6             Moderate           C  Eastern        Full             6.2
# ...                ...         ...      ...         ...             ...
# 6209               Low           C  Eastern        Full             6.3
# 6210               Low           C  Eastern        Full             6.8
# 6211               Low           C  Western        Full             6.2
# 6212               Low           C  Eastern        Full             5.9
# 6214               Low           C  Western        Full             5.9
#
#       Score_on_Plays_Made  Missed_Play_Score  School_Score  Overall_Score
# ...

# %%
df.drop(labels=['Region'],axis=1,inplace=True)
df.head()
# Out:
#   Injury_Propensity School_Type Scholarship  Academic_Score  \
# 0              High           A     Partial             7.0
# 1               Low           C     Partial             6.3
# 2          Moderate           C     Partial             8.1
# 3          Moderate           C     Partial             7.2
# 6          Moderate           C        Full             6.2
#
#    Score_on_Plays_Made  Missed_Play_Score  School_Score  Overall_Score
# 0                 0.27               0.36          0.45            8.8
# 1                 0.30               0.34          0.49            9.5
# 2                 0.28               0.40          0.44           10.1
# 3                 0.23               0.32          0.40            9.9
# 6                 0.32               0.16          0.47            9.6

# %%
df.drop(labels=['School_Type'],axis=1,inplace=True)
df.head()
# Out:
#   Injury_Propensity Scholarship  Academic_Score  Score_on_Plays_Made  \
# 0              High     Partial             7.0                 0.27
# 1               Low     Partial             6.3                 0.30
# 2          Moderate     Partial             8.1                 0.28
# 3          Moderate     Partial             7.2                 0.23
# 6          Moderate        Full             6.2                 0.32
#
#    Missed_Play_Score  School_Score  Overall_Score
# 0               0.36          0.45            8.8
# 1               0.34          0.49            9.5
# 2               0.40          0.44           10.1
# 3               0.32          0.40            9.9
# 6               0.16          0.47            9.6

# %%
cor = df.iloc[:,0:8].corr()
cor
# Out:
#                      Academic_Score  Score_on_Plays_Made  Missed_Play_Score  \
# Academic_Score             1.000000             0.232643           0.304536
# Score_on_Plays_Made        0.232643             1.000000          -0.380703
# Missed_Play_Score          0.304536            -0.380703           1.000000
# School_Score               0.288775             0.262143           0.044666
# Overall_Score             -0.105130            -0.059977          -0.011402
#
#                      School_Score  Overall_Score
# Academic_Score           0.288775      -0.105130
# Score_on_Plays_Made      0.262143      -0.059977
# Missed_Play_Score        0.044666      -0.011402
# School_Score             1.000000       0.004787
# Overall_Score            0.004787       1.000000

# %%
df.corr()
# Out:
#                      Academic_Score  Score_on_Plays_Made  Missed_Play_Score  \
# Academic_Score             1.000000             0.232643           0.304536
# Score_on_Plays_Made        0.232643             1.000000          -0.380703
# Missed_Play_Score          0.304536            -0.380703           1.000000
# School_Score               0.288775             0.262143           0.044666
# Overall_Score             -0.105130            -0.059977          -0.011402
#
#                      School_Score  Overall_Score
# Academic_Score           0.288775      -0.105130
# Score_on_Plays_Made      0.262143      -0.059977
# Missed_Play_Score        0.044666      -0.011402
# School_Score             1.000000       0.004787
# Overall_Score            0.004787       1.000000

# %%
plt.figure(figsize=(13,7))

sns.heatmap(cor,annot=True,mask=np.triu(cor,+1),cmap='RdYlGn');

# %%
# Pairplot using sns
sns.pairplot(df ,diag_kind='kde' ,hue='Overall_Score');
# Out:
# C:\Users\Pavan Krovi\anaconda3_new\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Pavan Krovi\anaconda3_new\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Pavan Krovi\anaconda3_new\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Pavan Krovi\anaconda3_new\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Pavan Krovi\anaconda3_new\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
df.iloc[:,0:8].hist();

# %%
## We are coding up the 'education' variable in an ordinal manner

df['Scholarship']=np.where(df['Scholarship'] =='Partial', '0', df['Scholarship'])
df['Scholarship']=np.where(df['Scholarship'] =='Full', '1', df['Scholarship'])

# %%
df.head()
# Out:
#   Injury_Propensity Scholarship  Academic_Score  Score_on_Plays_Made  \
# 0              High           0             7.0                 0.27
# 1               Low           0             6.3                 0.30
# 2          Moderate           0             8.1                 0.28
# 3          Moderate           0             7.2                 0.23
# 6          Moderate           1             6.2                 0.32
#
#    Missed_Play_Score  School_Score  Overall_Score
# 0               0.36          0.45            8.8
# 1               0.34          0.49            9.5
# 2               0.40          0.44           10.1
# 3               0.32          0.40            9.9
# 6               0.16          0.47            9.6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5268 entries, 0 to 6214
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Injury_Propensity    5268 non-null   object
#  1   Scholarship          5268 non-null   object
#  2   Academic_Score       5268 non-null   float64
#  3   Score_on_Plays_Made  5268 non-null   float64
#  4   Missed_Play_Score    5268 non-null   float64
#  5   School_Score         5268 non-null   float64
#  6   Overall_Score        5268 non-null   float64
# dtypes: float64(5), object(2)
# memory usage: 489.2+ KB

# %%
df['Scholarship'] = df['Scholarship'].astype('int64')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5268 entries, 0 to 6214
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Injury_Propensity    5268 non-null   object
#  1   Scholarship          5268 non-null   int64
#  2   Academic_Score       5268 non-null   float64
#  3   Score_on_Plays_Made  5268 non-null   float64
#  4   Missed_Play_Score    5268 non-null   float64
#  5   School_Score         5268 non-null   float64
#  6   Overall_Score        5268 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 489.2+ KB

# %%
## Converting the 'salary' Variable into numeric by using the LabelEncoder functionality inside sklearn.
from sklearn.preprocessing import LabelEncoder

## Defining a Label Encoder object instance
LE = LabelEncoder()

# %%
df['Overall_Score'] = LE.fit_transform(df['Overall_Score'])
df.head()
# Out:
#   Injury_Propensity  Scholarship  Academic_Score  Score_on_Plays_Made  \
# 0              High            0             7.0                 0.27
# 1               Low            0             6.3                 0.30
# 2          Moderate            0             8.1                 0.28
# 3          Moderate            0             7.2                 0.23
# 6          Moderate            1             6.2                 0.32
#
#    Missed_Play_Score  School_Score  Overall_Score
# 0               0.36          0.45              5
# 1               0.34          0.49             14
# 2               0.40          0.44             27
# 3               0.32          0.40             24
# 6               0.16          0.47             18

# %%
df['Academic_Score'] = LE.fit_transform(df['Academic_Score'])
df['Score_on_Plays_Made'] = LE.fit_transform(df['Score_on_Plays_Made'])
df['Missed_Play_Score'] = LE.fit_transform(df['Missed_Play_Score'])
df['School_Score'] = LE.fit_transform(df['School_Score'])

# %%
df.head()
# Out:
#   Injury_Propensity  Scholarship  Academic_Score  Score_on_Plays_Made  \
# 0              High            0              28                   35
# 1               Low            0              20                   41
# 2          Moderate            0              40                   37
# 3          Moderate            0              31                   27
# 6          Moderate            1              19                   45
#
#    Missed_Play_Score  School_Score  Overall_Score
# 0                 34            22              5
# 1                 32            26             14
# 2                 38            21             27
# 3                 30            17             24
# 6                 14            24             18

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5268 entries, 0 to 6214
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Injury_Propensity    5268 non-null   object
#  1   Scholarship          5268 non-null   int64
#  2   Academic_Score       5268 non-null   int64
#  3   Score_on_Plays_Made  5268 non-null   int64
#  4   Missed_Play_Score    5268 non-null   int64
#  5   School_Score         5268 non-null   int64
#  6   Overall_Score        5268 non-null   int64
# dtypes: int64(6), object(1)
# memory usage: 489.2+ KB

# %%
df_dummy = pd.get_dummies(df,drop_first=True)
df_dummy.head()
# Out:
#    Scholarship  Academic_Score  Score_on_Plays_Made  Missed_Play_Score  \
# 0            0              28                   35                 34
# 1            0              20                   41                 32
# 2            0              40                   37                 38
# 3            0              31                   27                 30
# 6            1              19                   45                 14
#
#    School_Score  Overall_Score  Injury_Propensity_Low  \
# 0            22              5                      0
# 1            26             14                      1
# 2            21             27                      0
# 3            17             24                      0
# 6            24             18                      0
#
#    Injury_Propensity_Moderate  Injury_Propensity_Normal
# 0                           0                         0
# 1                           0                         0
# ...

# %%
df_dummy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5268 entries, 0 to 6214
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Scholarship                 5268 non-null   int64
#  1   Academic_Score              5268 non-null   int64
#  2   Score_on_Plays_Made         5268 non-null   int64
#  3   Missed_Play_Score           5268 non-null   int64
#  4   School_Score                5268 non-null   int64
#  5   Overall_Score               5268 non-null   int64
#  6   Injury_Propensity_Low       5268 non-null   uint8
#  7   Injury_Propensity_Moderate  5268 non-null   uint8
#  8   Injury_Propensity_Normal    5268 non-null   uint8
# dtypes: int64(6), uint8(3)
# memory usage: 463.5 KB

# %% [markdown]
# # Build various iterations of the Logistic Regression model using appropriate variable selection techniques for the full data. Compare values of model selection criteria for proposed models. Compare as many criteria as you feel are suitable

# %%
import statsmodels.formula.api as sm

# %%
df_dummy.columns
# Out:
# Index(['Scholarship', 'Academic_Score', 'Score_on_Plays_Made',
#        'Missed_Play_Score', 'School_Score', 'Overall_Score',
#        'Injury_Propensity_Low', 'Injury_Propensity_Moderate',
#        'Injury_Propensity_Normal'],
#       dtype='object')

# %%
formula_1='Scholarship~Academic_Score+Score_on_Plays_Made+Missed_Play_Score+School_Score+Overall_Score+Injury_Propensity_Low+Injury_Propensity_Moderate+Injury_Propensity_Normal'

# %%
Logistic_1 = sm.logit(formula=formula_1,data=df_dummy).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.461844
#          Iterations 6

# %%
Logistic_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:            Scholarship   No. Observations:                 5268
# Model:                          Logit   Df Residuals:                     5259
# Method:                           MLE   Df Model:                            8
# Date:                Wed, 03 Feb 2021   Pseudo R-squ.:                  0.2971
# Time:                        21:41:16   Log-Likelihood:                -2433.0
# converged:                       True   LL-Null:                       -3461.6
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -4.9562      0.189    -26.288      0.000      -5.326      -4.587
# ...

# %%
def vif_cal(input_data):
    x_vars=input_data
    xvar_names=input_data.columns
    for i in range(0,xvar_names.shape[0]):
        y=x_vars[xvar_names[i]] 
        x=x_vars[xvar_names.drop(xvar_names[i])]
        rsq=sm.ols(formula="y~x", data=x_vars).fit().rsquared  
        vif=round(1/(1-rsq),2)
        print (xvar_names[i], " VIF = " , vif)

# %%
vif_cal(input_data=df_dummy.drop('Scholarship',axis=1))
# Out:
# Academic_Score  VIF =  1.39
# Score_on_Plays_Made  VIF =  1.45
# Missed_Play_Score  VIF =  1.48
# School_Score  VIF =  1.19
# Overall_Score  VIF =  1.18
# Injury_Propensity_Low  VIF =  2.4
# Injury_Propensity_Moderate  VIF =  1.71
# Injury_Propensity_Normal  VIF =  2.12

# %%
formula_2='Scholarship~Academic_Score+Score_on_Plays_Made+Missed_Play_Score+School_Score+Overall_Score+Injury_Propensity_Moderate+Injury_Propensity_Normal'

# %%
Logistic_2 = sm.logit(formula=formula_2,data=df_dummy).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.468200
#          Iterations 6

# %%
Logistic_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:            Scholarship   No. Observations:                 5268
# Model:                          Logit   Df Residuals:                     5260
# Method:                           MLE   Df Model:                            7
# Date:                Wed, 03 Feb 2021   Pseudo R-squ.:                  0.2875
# Time:                        21:41:25   Log-Likelihood:                -2466.5
# converged:                       True   LL-Null:                       -3461.6
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -4.4894      0.174    -25.832      0.000      -4.830      -4.149
# ...

# %%
vif_cal(input_data=df_dummy.drop(['Scholarship','Injury_Propensity_Low'],axis=1))
# Out:
# Academic_Score  VIF =  1.37
# Score_on_Plays_Made  VIF =  1.45
# Missed_Play_Score  VIF =  1.44
# School_Score  VIF =  1.17
# Overall_Score  VIF =  1.05
# Injury_Propensity_Moderate  VIF =  1.1
# Injury_Propensity_Normal  VIF =  1.1

# %%
formula_3='Scholarship~Academic_Score+Score_on_Plays_Made+Missed_Play_Score+School_Score+Overall_Score+Injury_Propensity_Moderate'

# %%
Logistic_3 = sm.logit(formula=formula_3,data=df_dummy).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.468246
#          Iterations 6

# %%
Logistic_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:            Scholarship   No. Observations:                 5268
# Model:                          Logit   Df Residuals:                     5261
# Method:                           MLE   Df Model:                            6
# Date:                Wed, 03 Feb 2021   Pseudo R-squ.:                  0.2874
# Time:                        21:41:30   Log-Likelihood:                -2466.7
# converged:                       True   LL-Null:                       -3461.6
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -4.4921      0.174    -25.848      0.000      -4.833      -4.151
# ...

# %%
vif_cal(input_data=df_dummy.drop(['Scholarship','Injury_Propensity_Low','Injury_Propensity_Normal'],axis=1))
# Out:
# Academic_Score  VIF =  1.37
# Score_on_Plays_Made  VIF =  1.44
# Missed_Play_Score  VIF =  1.44
# School_Score  VIF =  1.17
# Overall_Score  VIF =  1.02
# Injury_Propensity_Moderate  VIF =  1.05

# %% [markdown]
# # Split the data into training (70%) and test (30%). Build the various iterations of the Linear Regression models on the training data and use those models to predict on the test data using appropriate model evaluation metrics.

# %%
from sklearn.model_selection import train_test_split

# %%
Train,Test = train_test_split(df_dummy,test_size=0.3,random_state=1,stratify=df_dummy['Scholarship'])

# %%
Train.shape
# Out:
# (3687, 9)

# %%
Test.shape
# Out:
# (1581, 9)

# %%
Train['Scholarship'].value_counts(1)
# Out:
# 0    0.633577
# 1    0.366423
# Name: Scholarship, dtype: float64

# %%
Test['Scholarship'].value_counts(1)
# Out:
# 0    0.633144
# 1    0.366856
# Name: Scholarship, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression(solver='newton-cg',penalty='none')

# %%
model_1 = LR.fit(Train[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Moderate','Injury_Propensity_Normal']],Train['Scholarship'])

# %%
print('Accuracy Score of Model 1:',model_1.score(Train[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Moderate','Injury_Propensity_Normal']],Train['Scholarship']))
# Out:
# Accuracy Score of Model 1: 0.8272308109574179

# %%
model_1_test_class = model_1.predict(Test[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Moderate','Injury_Propensity_Normal']])
model_1_test_probabilities = model_1.predict_proba(Test[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Moderate','Injury_Propensity_Normal']])

# %%
model_2 = LR.fit(Train[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Moderate','Injury_Propensity_Normal']],Train['Scholarship'])

# %%
print('Accuracy Score of Model 2:',model_2.score(Train[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Moderate','Injury_Propensity_Normal']],Train['Scholarship']))
# Out:
# Accuracy Score of Model 2: 0.8212639001898563

# %%
model_2_test_class = model_2.predict(Test[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Moderate','Injury_Propensity_Normal']])
model_2_test_probabilities = model_2.predict_proba(Test[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Moderate','Injury_Propensity_Normal']])

# %%
model_3 = LR.fit(Train[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Normal']],Train['Scholarship'])

# %%
print('Accuracy Score of Model 3:',model_3.score(Train[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Normal']],Train['Scholarship']))
# Out:
# Accuracy Score of Model 3: 0.82804448060754

# %%
model_3_test_class = model_3.predict(Test[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Normal']])
model_3_test_probabilities = model_3.predict_proba(Test[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Normal']])

# %%
model_4 = LR.fit(Train[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Moderate']],Train['Scholarship'])

# %%
print('Accuracy Score of Model 4:',model_4.score(Train[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Moderate']],Train['Scholarship']))
# Out:
# Accuracy Score of Model 4: 0.8302142663411988

# %%
model_4_test_class = model_4.predict(Test[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Moderate']])
model_4_test_probabilities = model_4.predict_proba(Test[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Moderate']])

# %% [markdown]
# # Evaluate the Four models on the test data using the various statistics of the confusion matrix.

# %%
from sklearn import metrics

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 15,4

# %%
f,a =  plt.subplots(1,4,sharex=True,sharey=True,squeeze=False)

#Plotting confusion matrix for the different models for the Training Data

plot_0 = sns.heatmap((metrics.confusion_matrix(Test['Scholarship'],model_1_test_class)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][0]);
a[0][0].set_title('Model_1')

plot_1 = sns.heatmap((metrics.confusion_matrix(Test['Scholarship'],model_2_test_class)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][1]);
a[0][1].set_title('Model 2');

plot_1 = sns.heatmap((metrics.confusion_matrix(Test['Scholarship'],model_3_test_class)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][2]);
a[0][2].set_title('Model 3');

plot_1 = sns.heatmap((metrics.confusion_matrix(Test['Scholarship'],model_4_test_class)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][3]);
a[0][3].set_title('Model 4');

# %%
print('Model 1')
tn, fp, fn, tp = metrics.confusion_matrix(Test['Scholarship'],model_1_test_class).ravel()
print('True Negative:',tn,'\n''False Positives:' ,fp,'\n''False Negatives:', fn,'\n''True Positives:', tp,'\n\n')

print('Model 2')
tn, fp, fn, tp = metrics.confusion_matrix(Test['Scholarship'],model_2_test_class).ravel()
print('True Negative:',tn,'\n''False Positives:' ,fp,'\n''False Negatives:', fn,'\n''True Positives:', tp,'\n\n')

print('Model 3')
tn, fp, fn, tp = metrics.confusion_matrix(Test['Scholarship'],model_3_test_class).ravel()
print('True Negative:',tn,'\n''False Positives:' ,fp,'\n''False Negatives:', fn,'\n''True Positives:', tp,'\n\n')

print('Model 4')
tn, fp, fn, tp = metrics.confusion_matrix(Test['Scholarship'],model_4_test_class).ravel()
print('True Negative:',tn,'\n''False Positives:' ,fp,'\n''False Negatives:', fn,'\n''True Positives:', tp)
# Out:
# Model 1
# True Negative: 933
# False Positives: 68
# False Negatives: 213
# True Positives: 367
#
#
# Model 2
# True Negative: 926
# False Positives: 75
# False Negatives: 224
# True Positives: 356
#
#
# Model 3
# True Negative: 936
# False Positives: 65
# False Negatives: 212
# True Positives: 368
#
#
# Model 4
# True Negative: 929
# False Positives: 72
# False Negatives: 214
# True Positives: 366

# %%
print('Model 1')
print(metrics.classification_report(Test['Scholarship'],model_1_test_class),'\n')

print('Model 2')
print(metrics.classification_report(Test['Scholarship'],model_2_test_class),'\n')

print('Model 3')
print(metrics.classification_report(Test['Scholarship'],model_3_test_class),'\n')

print('Model 4')
print(metrics.classification_report(Test['Scholarship'],model_4_test_class))
# Out:
# Model 1
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.87      1001
#            1       0.84      0.63      0.72       580
#
#     accuracy                           0.82      1581
#    macro avg       0.83      0.78      0.80      1581
# weighted avg       0.82      0.82      0.82      1581
#
#
# Model 2
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.86      1001
#            1       0.83      0.61      0.70       580
#
#     accuracy                           0.81      1581
#    macro avg       0.82      0.77      0.78      1581
# weighted avg       0.81      0.81      0.80      1581
#
#
# Model 3
#               precision    recall  f1-score   support
#
#            0       0.82      0.94      0.87      1001
#            1       0.85      0.63      0.73       580
#
#     accuracy                           0.82      1581
# ...

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 15,8

# %%
# AUC and ROC for the model 1


# calculating on the basis of a person not defaulting
# calculate AUC
auc = metrics.roc_auc_score(Test['Scholarship'],model_1_test_probabilities[:, 1])#keeping only the probabilities for the desired class outcome
print('Model 1 AUC: %.5f' % auc)
# # calculate roc curve
# from sklearn.metrics import roc_curve
fpr, tpr, thresholds = metrics.roc_curve(Test['Scholarship'],model_1_test_probabilities[:, 1])#keeping only the probabilities for the desired 
#class outcome
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()


# AUC and ROC for the model 2


# calculating on the basis of a person not defaulting
# calculate AUC
auc = metrics.roc_auc_score(Test['Scholarship'],model_2_test_probabilities[:, 1])#keeping only the probabilities for the desired class outcome
print('Model 2 AUC: %.5f' % auc)
# # calculate roc curve
# from sklearn.metrics import roc_curve
fpr, tpr, thresholds = metrics.roc_curve(Test['Scholarship'],model_2_test_probabilities[:, 1])#keeping only the probabilities for the desired 
#class outcome
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()

# AUC and ROC for the model 3


# calculating on the basis of a person not defaulting
# calculate AUC
auc = metrics.roc_auc_score(Test['Scholarship'],model_3_test_probabilities[:, 1])#keeping only the probabilities for the desired class outcome
print('Model 3 AUC: %.5f' % auc)
# # calculate roc curve
# from sklearn.metrics import roc_curve
fpr, tpr, thresholds = metrics.roc_curve(Test['Scholarship'],model_3_test_probabilities[:, 1])#keeping only the probabilities for the desired 
#class outcome
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()

# calculating on the basis of a person not defaulting
# calculate AUC

auc = metrics.roc_auc_score(Test['Scholarship'],model_4_test_probabilities[:, 1])#keeping only the probabilities for the desired class outcome
print('Model 4 AUC: %.5f' % auc)
# # calculate roc curve
# from sklearn.metrics import roc_curve
fpr, tpr, thresholds = metrics.roc_curve(Test['Scholarship'],model_4_test_probabilities[:, 1])#keeping only the probabilities for the desired 
#class outcome
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# Model 1 AUC: 0.80599
# Model 2 AUC: 0.80547
# Model 3 AUC: 0.80606
# Model 4 AUC: 0.80588

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
LDA = LinearDiscriminantAnalysis()

# %% [markdown]
# # Build three Linear Discriminant Analysis models [using the variables used in the three different models of Logistic Regression] on the training data, check their accuracy scores on the training data and use those models to predict the classes and the corresponding probabilities on the test data.

# %%
model_1_LDA = LDA.fit(Train[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Moderate','Injury_Propensity_Normal']],Train['Scholarship'])

# %%
print('Accuracy Score of LDA Model 1:',model_1_LDA.score(Train[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Moderate','Injury_Propensity_Normal']],Train['Scholarship']))
# Out:
# Accuracy Score of LDA Model 1: 0.8291293734743694

# %% [markdown]
# #  Model 1 - Predicting the classes and the probabilities on the Test Data for the LDA model

# %%
model_1_LDA_test_class = model_1_LDA.predict(Test[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Moderate','Injury_Propensity_Normal']])
model_1_LDA_test_probabilities = model_1_LDA.predict_proba(Test[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Moderate','Injury_Propensity_Normal']])

# %% [markdown]
# # Model 2 - Building the LDA model on the Training Data and checking the Accuracy score on the training data.

# %%
model_2_LDA = LDA.fit(Train[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Moderate','Injury_Propensity_Normal']],Train['Scholarship'])

# %%
print('Accuracy Score of LDA Model 2:',model_2_LDA.score(Train[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Moderate','Injury_Propensity_Normal']],Train['Scholarship']))
# Out:
# Accuracy Score of LDA Model 2: 0.8223487930566856

# %% [markdown]
# Model 2 - Predicting the classes and the probabilities on the Test Data for the LDA model

# %%
model_2_LDA_test_class = model_2_LDA.predict(Test[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Moderate','Injury_Propensity_Normal']])
model_2_LDA_test_probabilities = model_2_LDA.predict_proba(Test[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Moderate','Injury_Propensity_Normal']])

# %% [markdown]
# Model 3 - Building the LDA model on the Training Data and checking the Accuracy score on the training data.

# %%
model_3_LDA = LDA.fit(Train[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Normal']],Train['Scholarship'])

# %%
print('Accuracy Score of LDA Model 2:',model_3_LDA.score(Train[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Normal']],Train['Scholarship']))
# Out:
# Accuracy Score of LDA Model 2: 0.8288581502576621

# %% [markdown]
# Model 3 - Predicting the classes and the probabilities on the Test Data for the LDA model

# %%
model_3_LDA_test_class = model_3_LDA.predict(Test[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Normal']])
model_3_LDA_test_probabilities = model_3_LDA.predict_proba(Test[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Normal']])

# %% [markdown]
# Model 4  - Building the LDA model on the Training Data and checking the Accuracy score on the training data.

# %%
model_4_LDA = LDA.fit(Train[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Moderate']],Train['Scholarship'])

# %%
print('Accuracy Score of LDA Model 4:',model_4_LDA.score(Train[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Moderate']],Train['Scholarship']))
# Out:
# Accuracy Score of LDA Model 4: 0.8323840520748577

# %%
model_4_LDA_test_class = model_4_LDA.predict(Test[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Moderate']])
model_4_LDA_test_probabilities = model_4_LDA.predict_proba(Test[['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score','Injury_Propensity_Low','Injury_Propensity_Moderate']])

# %% [markdown]
# # Evaluate the three LDA models on the test data using the various statistics of the confusion matrix and the AUC-ROC curve.

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 15,4

# %%
f,a =  plt.subplots(1,4,sharex=True,sharey=True,squeeze=False)

#Plotting confusion matrix for the different models for the Training Data

plot_0 = sns.heatmap((metrics.confusion_matrix(Test['Scholarship'],model_1_LDA_test_class)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][0]);
a[0][0].set_title('LDA Model_1')

plot_1 = sns.heatmap((metrics.confusion_matrix(Test['Scholarship'],model_2_LDA_test_class)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][1]);
a[0][1].set_title('LDA Model 2');

plot_1 = sns.heatmap((metrics.confusion_matrix(Test['Scholarship'],model_3_LDA_test_class)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][2]);
a[0][2].set_title('LDA Model 3');

plot_1 = sns.heatmap((metrics.confusion_matrix(Test['Scholarship'],model_3_LDA_test_class)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][3]);
a[0][3].set_title('LDA Model 4');

# %%
print('LDA Model 1')
tn, fp, fn, tp = metrics.confusion_matrix(Test['Scholarship'],model_1_LDA_test_class).ravel()
print('True Negative:',tn,'\n''False Positives:' ,fp,'\n''False Negatives:', fn,'\n''True Positives:', tp,'\n\n')

print('LDA Model 2')
tn, fp, fn, tp = metrics.confusion_matrix(Test['Scholarship'],model_2_LDA_test_class).ravel()
print('True Negative:',tn,'\n''False Positives:' ,fp,'\n''False Negatives:', fn,'\n''True Positives:', tp,'\n\n')

print('LDA Model 3')
tn, fp, fn, tp = metrics.confusion_matrix(Test['Scholarship'],model_3_LDA_test_class).ravel()
print('True Negative:',tn,'\n''False Positives:' ,fp,'\n''False Negatives:', fn,'\n''True Positives:', tp,'\n\n')

print('LDA Model 4')
tn, fp, fn, tp = metrics.confusion_matrix(Test['Scholarship'],model_4_LDA_test_class).ravel()
print('True Negative:',tn,'\n''False Positives:' ,fp,'\n''False Negatives:', fn,'\n''True Positives:', tp)
# Out:
# LDA Model 1
# True Negative: 938
# False Positives: 63
# False Negatives: 219
# True Positives: 361
#
#
# LDA Model 2
# True Negative: 930
# False Positives: 71
# False Negatives: 227
# True Positives: 353
#
#
# LDA Model 3
# True Negative: 939
# False Positives: 62
# False Negatives: 221
# True Positives: 359
#
#
# LDA Model 4
# True Negative: 936
# False Positives: 65
# False Negatives: 220
# True Positives: 360

# %%
print('LDA Model 1')
print(metrics.classification_report(Test['Scholarship'],model_1_LDA_test_class),'\n')

print('LDA Model 2')
print(metrics.classification_report(Test['Scholarship'],model_2_LDA_test_class),'\n')

print('LDA Model 3')
print(metrics.classification_report(Test['Scholarship'],model_3_LDA_test_class),'\n')

print('LDA Model 4')
print(metrics.classification_report(Test['Scholarship'],model_4_LDA_test_class))
# Out:
# LDA Model 1
#               precision    recall  f1-score   support
#
#            0       0.81      0.94      0.87      1001
#            1       0.85      0.62      0.72       580
#
#     accuracy                           0.82      1581
#    macro avg       0.83      0.78      0.79      1581
# weighted avg       0.83      0.82      0.81      1581
#
#
# LDA Model 2
#               precision    recall  f1-score   support
#
#            0       0.80      0.93      0.86      1001
#            1       0.83      0.61      0.70       580
#
#     accuracy                           0.81      1581
#    macro avg       0.82      0.77      0.78      1581
# weighted avg       0.81      0.81      0.80      1581
#
#
# LDA Model 3
#               precision    recall  f1-score   support
#
#            0       0.81      0.94      0.87      1001
#            1       0.85      0.62      0.72       580
#
#     accuracy                           0.82      1581
# ...

# %%
# AUC and ROC for the model 1


# calculating on the basis of a person not defaulting
# calculate AUC
auc = metrics.roc_auc_score(Test['Scholarship'],model_1_LDA_test_probabilities[:, 1])#keeping only the probabilities for the desired class outcome
print('LDA Model 1 AUC: %.5f' % auc)
# # calculate roc curve
# from sklearn.metrics import roc_curve
fpr, tpr, thresholds = metrics.roc_curve(Test['Scholarship'],model_1_LDA_test_probabilities[:, 1])#keeping only the probabilities for the desired 
#class outcome
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()


# AUC and ROC for the model 2


# calculating on the basis of a person not defaulting
# calculate AUC
auc = metrics.roc_auc_score(Test['Scholarship'],model_2_LDA_test_probabilities[:, 1])#keeping only the probabilities for the desired class outcome
print('LDA Model 2 AUC: %.5f' % auc)
# # calculate roc curve
# from sklearn.metrics import roc_curve
fpr, tpr, thresholds = metrics.roc_curve(Test['Scholarship'],model_2_LDA_test_probabilities[:, 1])#keeping only the probabilities for the desired 
#class outcome
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()

# AUC and ROC for the model 3


# calculating on the basis of a person not defaulting
# calculate AUC
auc = metrics.roc_auc_score(Test['Scholarship'],model_3_LDA_test_probabilities[:, 1])#keeping only the probabilities for the desired class outcome
print('LDA Model 3 AUC: %.5f' % auc)
# # calculate roc curve
# from sklearn.metrics import roc_curve
fpr, tpr, thresholds = metrics.roc_curve(Test['Scholarship'],model_3_LDA_test_probabilities[:, 1])#keeping only the probabilities for the desired 
#class outcome
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()

# calculating on the basis of a person not defaulting
# calculate AUC
auc = metrics.roc_auc_score(Test['Scholarship'],model_4_LDA_test_probabilities[:, 1])#keeping only the probabilities for the desired class outcome
print('LDA Model 4 AUC: %.5f' % auc)
# # calculate roc curve
# from sklearn.metrics import roc_curve
fpr, tpr, thresholds = metrics.roc_curve(Test['Scholarship'],model_4_LDA_test_probabilities[:, 1])#keeping only the probabilities for the desired 
#class outcome
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# LDA Model 1 AUC: 0.80575
# LDA Model 2 AUC: 0.80524
# LDA Model 3 AUC: 0.80610
# LDA Model 4 AUC: 0.80573
