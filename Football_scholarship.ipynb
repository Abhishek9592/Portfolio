# %%
import numpy as np   
import pandas as pd    
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Read the data from the ‘.csv’ file. Check the dimensions, data types of different variables, missing values and the basic measures of descriptive statistics for the continuous variables.

# %%
df = pd.read_csv('Football_Scholarship.csv')

# %%
df.head()
# Out:
#    Academic_Score  Score_on_Plays_Made  Missed_Play_Score Injury_Propensity  \
# 0             7.0                 0.27               0.36              High
# 1             6.3                 0.30               0.34               Low
# 2             8.1                 0.28               0.40          Moderate
# 3             7.2                 0.23               0.32          Moderate
# 4             7.2                 0.23               0.32          Moderate
#
#   School_Type  School_Score  Overall_Score   Region Scholarship
# 0           A          0.45            8.8  Eastern     Partial
# 1           C          0.49            9.5  Eastern     Partial
# 2           C          0.44           10.1  Eastern     Partial
# 3           C          0.40            9.9  Eastern     Partial
# 4           C          0.40            9.9  Eastern     Partial

# %%
df.shape
# Out:
# (6215, 9)

# %%
print('The number of rows (observations) is',df.shape[0],'\n''The number of columns (variables) is',df.shape[1])
# Out:
# The number of rows (observations) is 6215
# The number of columns (variables) is 9

# %%
df.isnull().sum()
# Out:
# Academic_Score         0
# Score_on_Plays_Made    0
# Missed_Play_Score      0
# Injury_Propensity      0
# School_Type            0
# School_Score           0
# Overall_Score          0
# Region                 0
# Scholarship            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6215 entries, 0 to 6214
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Academic_Score       6215 non-null   float64
#  1   Score_on_Plays_Made  6215 non-null   float64
#  2   Missed_Play_Score    6215 non-null   float64
#  3   Injury_Propensity    6215 non-null   object
#  4   School_Type          6215 non-null   object
#  5   School_Score         6215 non-null   float64
#  6   Overall_Score        6215 non-null   float64
#  7   Region               6215 non-null   object
#  8   Scholarship          6215 non-null   object
# dtypes: float64(5), object(4)
# memory usage: 437.1+ KB

# %%
df.isnull().sum()
# Out:
# Academic_Score         0
# Score_on_Plays_Made    0
# Missed_Play_Score      0
# Injury_Propensity      0
# School_Type            0
# School_Score           0
# Overall_Score          0
# Region                 0
# Scholarship            0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#         Academic_Score  Score_on_Plays_Made  Missed_Play_Score  \
# count      6215.000000          6215.000000        6215.000000
# unique             NaN                  NaN                NaN
# top                NaN                  NaN                NaN
# freq               NaN                  NaN                NaN
# mean          7.219252             0.337338           0.319537
# std           1.292237             0.160122           0.145153
# min           3.800000             0.080000           0.000000
# 25%           6.400000             0.230000           0.250000
# 50%           7.000000             0.290000           0.310000
# 75%           7.700000             0.400000           0.390000
# max          15.900000             1.330000           1.660000
#
#        Injury_Propensity School_Type  School_Score  Overall_Score   Region  \
# count               6215        6215   6215.000000    6215.000000     6215
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 6210    False
# 6211    False
# 6212    False
# 6213     True
# 6214    False
# Length: 6215, dtype: bool

# %%
duplicate = df[df.duplicated()] 
print("Duplicated rows:")
duplicate
# Out:
# Duplicated rows:
#       Academic_Score  Score_on_Plays_Made  Missed_Play_Score  \
# 4                7.2                0.230               0.32
# 5                8.1                0.280               0.40
# 7                7.0                0.270               0.36
# 8                6.3                0.300               0.34
# 36               7.3                0.240               0.39
# ...              ...                  ...                ...
# 6180             7.2                0.695               0.13
# 6181             7.2                0.695               0.13
# 6184             7.2                0.695               0.13
# 6198             6.2                0.560               0.09
# 6213             6.3                0.510               0.13
#
#      Injury_Propensity School_Type  School_Score  Overall_Score    Region  \
# 4             Moderate           C          0.40            9.9   Eastern
# ...

# %%
duplicate.shape
# Out:
# (947, 9)

# %%
df.drop_duplicates(keep=False,inplace=True)

# %%
duplicate = df[df.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [Academic_Score, Score_on_Plays_Made, Missed_Play_Score, Injury_Propensity, School_Type, School_Score, Overall_Score, Region, Scholarship]
# Index: []

# %%
df
# Out:
#       Academic_Score  Score_on_Plays_Made  Missed_Play_Score  \
# 6                6.2                0.320               0.16
# 9                8.1                0.220               0.43
# 10               8.1                0.270               0.41
# 11               8.6                0.230               0.40
# 12               7.9                0.180               0.37
# ...              ...                  ...                ...
# 6208             5.4                0.740               0.09
# 6210             6.8                0.620               0.08
# 6211             6.2                0.600               0.08
# 6212             5.9                0.550               0.10
# 6214             5.9                0.645               0.12
#
#      Injury_Propensity School_Type  School_Score  Overall_Score    Region  \
# 6             Moderate           C          0.47            9.6   Eastern
# 9                  Low           C          0.45           11.0   Eastern
# ...

# %%
df.describe()
# Out:
#        Academic_Score  Score_on_Plays_Made  Missed_Play_Score  School_Score  \
# count     4462.000000          4462.000000        4462.000000   4462.000000
# mean         7.180356             0.336551           0.320950      0.531044
# std          1.296063             0.162466           0.146872      0.146186
# min          3.800000             0.080000           0.000000      0.220000
# 25%          6.400000             0.230000           0.250000      0.430000
# 50%          6.900000             0.290000           0.310000      0.510000
# 75%          7.700000             0.400000           0.400000      0.600000
# max         15.900000             1.330000           1.660000      1.980000
#
#        Overall_Score
# count    4462.000000
# mean       10.541408
# std         1.164961
# min         8.000000
# 25%         9.500000
# 50%        10.400000
# 75%        11.300000
# max        14.900000

# %%
for feature in df.columns: 
    if df[feature].dtype == 'object': 
        print(feature)
        print(df[feature].value_counts())
        print('\n')
# Out:
# Injury_Propensity
# Low         2019
# Normal      1013
# Moderate     740
# High         690
# Name: Injury_Propensity, dtype: int64
#
#
# School_Type
# C    2482
# B    1281
# D     603
# A      96
# Name: School_Type, dtype: int64
#
#
# Region
# Eastern     2039
# Western     1237
# Southern    1186
# Name: Region, dtype: int64
#
#
# Scholarship
# Partial    2767
# Full       1695
# Name: Scholarship, dtype: int64

# %%
cat= []
num = []

# %%
for i in df.columns:
  if df[i].dtype == 'object':
    cat.append(i)
  else:
    num.append(i)
print("Categorical Values:")
print(cat)
print("Numeric Values:")
print(num)
# Out:
# Categorical Values:
# ['Injury_Propensity', 'School_Type', 'Region', 'Scholarship']
# Numeric Values:
# ['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score', 'School_Score', 'Overall_Score']

# %%
df1 = df

# %%
df1['Scholarship'] = df1['Scholarship'].replace({'Full':'1', 'Partial':'0'})

# %%
df1.head()
# Out:
#     Academic_Score  Score_on_Plays_Made  Missed_Play_Score Injury_Propensity  \
# 6              6.2                 0.32               0.16          Moderate
# 9              8.1                 0.22               0.43               Low
# 10             8.1                 0.27               0.41               Low
# 11             8.6                 0.23               0.40            Normal
# 12             7.9                 0.18               0.37               Low
#
#    School_Type  School_Score  Overall_Score    Region Scholarship
# 6            C          0.47            9.6   Eastern           1
# 9            C          0.45           11.0   Eastern           0
# 10           B          0.56           12.0  Southern           0
# 11           C          0.53            9.7  Southern           0
# 12           B          0.63           10.8  Southern           0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4462 entries, 6 to 6214
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Academic_Score       4462 non-null   float64
#  1   Score_on_Plays_Made  4462 non-null   float64
#  2   Missed_Play_Score    4462 non-null   float64
#  3   Injury_Propensity    4462 non-null   object
#  4   School_Type          4462 non-null   object
#  5   School_Score         4462 non-null   float64
#  6   Overall_Score        4462 non-null   float64
#  7   Region               4462 non-null   object
#  8   Scholarship          4462 non-null   object
# dtypes: float64(5), object(4)
# memory usage: 348.6+ KB

# %%
df1['Scholarship'].value_counts()
# Out:
# 0    2767
# 1    1695
# Name: Scholarship, dtype: int64

# %% [markdown]
# ### 2. Perform univariate Exploratory Data Analysis for the continuous variables to check for outliers at a distance of 1.5 times the Inter-Quartile Range. Also, check the correlation amongst the various continuous variables.

# %% [markdown]
# ### Box Plots

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 19,12

# %%
f,a =  plt.subplots(2,2)

plot_00 = sns.boxplot(df['Score_on_Plays_Made'],ax=a[0][0]);
a[0][0].set_title('Score_on_Plays_Made Boxplot')
plot_01 = sns.boxplot(df['Missed_Play_Score'],ax=a[0][1]);
a[0][1].set_title('Missed_Play_Score Boxplot')



plot_10 = sns.boxplot(df['Academic_Score'],ax=a[1][0]);
a[1][0].set_title('Academic_Score Boxplot')
plot_11 = sns.boxplot(df['School_Score'],ax=a[1][1]);
a[1][1].set_title('School_Score Boxplot');

# %%
plt.figure(figsize=(15,4))
sns.boxplot(df['Overall_Score'])

# %%
cols = ['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score']
for i in cols:
    sns.boxplot(df[i],whis=1.5)
    plt.grid()
    plt.show();

# %%
# # Defining a function for getting the Upper and Lower limt acceptance of the outliers at 1.5*IQR. 
# # We can choose to treat the outliers at 3*IQR as well
def remove_outlier(col):
    sorted(col)
    Q1,Q3=np.percentile(col,[25,75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
# This is a loop to treat outliers for all the non-'object' type varible

for column in df.columns:
    if df[column].dtype != 'object': 
        lr,ur=remove_outlier(df[column])
        df[column]=np.where(df[column]>ur,ur,df[column])
        df[column]=np.where(df[column]<lr,lr,df[column])

# %%
cols = ['Academic_Score','Score_on_Plays_Made','Missed_Play_Score','School_Score','Overall_Score']
for i in cols:
    sns.boxplot(df[i],whis=1.5)
    plt.grid()
    plt.show();

# %%
cor = df.iloc[:,0:8].corr()
cor
# Out:
#                      Academic_Score  Score_on_Plays_Made  Missed_Play_Score  \
# Academic_Score             1.000000             0.223432           0.307580
# Score_on_Plays_Made        0.223432             1.000000          -0.380056
# Missed_Play_Score          0.307580            -0.380056           1.000000
# School_Score               0.289007             0.265773           0.051252
# Overall_Score             -0.108340            -0.070778          -0.007355
#
#                      School_Score  Overall_Score
# Academic_Score           0.289007      -0.108340
# Score_on_Plays_Made      0.265773      -0.070778
# Missed_Play_Score        0.051252      -0.007355
# School_Score             1.000000      -0.000226
# Overall_Score           -0.000226       1.000000

# %%
df.corr()
# Out:
#                      Academic_Score  Score_on_Plays_Made  Missed_Play_Score  \
# Academic_Score             1.000000             0.223432           0.307580
# Score_on_Plays_Made        0.223432             1.000000          -0.380056
# Missed_Play_Score          0.307580            -0.380056           1.000000
# School_Score               0.289007             0.265773           0.051252
# Overall_Score             -0.108340            -0.070778          -0.007355
#
#                      School_Score  Overall_Score
# Academic_Score           0.289007      -0.108340
# Score_on_Plays_Made      0.265773      -0.070778
# Missed_Play_Score        0.051252      -0.007355
# School_Score             1.000000      -0.000226
# Overall_Score           -0.000226       1.000000

# %%
plt.figure(figsize=(13,7))

sns.heatmap(cor,annot=True,mask=np.triu(cor,+1),cmap='RdYlGn');

# %%
# Pairplot using sns
sns.pairplot(df ,diag_kind='kde' ,hue='Overall_Score');
# Out:
# D:\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# D:\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# D:\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# D:\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# D:\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
df.iloc[:,0:8].hist();

# %%
data = pd.get_dummies(df1,drop_first=True)
data.head()
# Out:
#     Academic_Score  Score_on_Plays_Made  Missed_Play_Score  School_Score  \
# 6              6.2                 0.32               0.16          0.47
# 9              8.1                 0.22               0.43          0.45
# 10             8.1                 0.27               0.41          0.56
# 11             8.6                 0.23               0.40          0.53
# 12             7.9                 0.18               0.37          0.63
#
#     Overall_Score  Injury_Propensity_Low  Injury_Propensity_Moderate  \
# 6             9.6                      0                           1
# 9            11.0                      1                           0
# 10           12.0                      1                           0
# 11            9.7                      0                           0
# 12           10.8                      1                           0
#
#     Injury_Propensity_Normal  School_Type_B  School_Type_C  School_Type_D  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4462 entries, 6 to 6214
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Academic_Score              4462 non-null   float64
#  1   Score_on_Plays_Made         4462 non-null   float64
#  2   Missed_Play_Score           4462 non-null   float64
#  3   School_Score                4462 non-null   float64
#  4   Overall_Score               4462 non-null   float64
#  5   Injury_Propensity_Low       4462 non-null   uint8
#  6   Injury_Propensity_Moderate  4462 non-null   uint8
#  7   Injury_Propensity_Normal    4462 non-null   uint8
#  8   School_Type_B               4462 non-null   uint8
#  9   School_Type_C               4462 non-null   uint8
#  10  School_Type_D               4462 non-null   uint8
#  11  Region_Southern             4462 non-null   uint8
#  12  Region_Western              4462 non-null   uint8
# ...

# %%
import statsmodels.formula.api as SM

# %%
data.columns
# Out:
# Index(['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
#        'School_Score', 'Overall_Score', 'Injury_Propensity_Low',
#        'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
#        'School_Type_B', 'School_Type_C', 'School_Type_D', 'Region_Southern',
#        'Region_Western', 'Scholarship_1'],
#       dtype='object')

# %% [markdown]
# #### Model 1

# %%
f_1 = 'Scholarship_1~Score_on_Plays_Made'

# %%
model_1 = SM.logit(formula=f_1,data=data).fit()
model_1.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.558838
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:          Scholarship_1   No. Observations:                 4462
# Model:                          Logit   Df Residuals:                     4460
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 07 Feb 2021   Pseudo R-squ.:                  0.1584
# Time:                        21:09:46   Log-Likelihood:                -2493.5
# converged:                       True   LL-Null:                       -2962.8
# Covariance Type:            nonrobust   LLR p-value:                4.216e-206
# ...
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
print('The adjusted pseudo R-square value is',1 - ((model_1.llf - model_1.df_model)/model_1.llnull))
# Out:
# The adjusted pseudo R-square value is 0.15804232250705474

# %% [markdown]
# #### Model 2

# %%
f_2 = 'Scholarship_1~Score_on_Plays_Made+Academic_Score'

# %%
model_2 = SM.logit(formula=f_2,data=data).fit()
model_2.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.518559
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:          Scholarship_1   No. Observations:                 4462
# Model:                          Logit   Df Residuals:                     4459
# Method:                           MLE   Df Model:                            2
# Date:                Sun, 07 Feb 2021   Pseudo R-squ.:                  0.2190
# Time:                        21:09:53   Log-Likelihood:                -2313.8
# converged:                       True   LL-Null:                       -2962.8
# Covariance Type:            nonrobust   LLR p-value:                1.430e-282
# ...
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
print('The adjusted pseudo R-square value is',1 - ((model_2.llf - model_2.df_model)/model_2.llnull))
# Out:
# The adjusted pseudo R-square value is 0.21836631309626142

# %%
data.columns
# Out:
# Index(['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
#        'School_Score', 'Overall_Score', 'Injury_Propensity_Low',
#        'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
#        'School_Type_B', 'School_Type_C', 'School_Type_D', 'Region_Southern',
#        'Region_Western', 'Scholarship_1'],
#       dtype='object')

# %% [markdown]
# #### Model 3

# %% [markdown]
# Backward Elimination
# In the above steps, we added columns to model.
#
# Now let's build model by starting with all columns and then drop columns as needed

# %%
f_3 = 'Scholarship_1~Academic_Score + Score_on_Plays_Made + Missed_Play_Score+School_Score + Overall_Score + Injury_Propensity_Low + Injury_Propensity_Moderate + Injury_Propensity_Normal + School_Type_B + School_Type_C + School_Type_D + Region_Southern + Region_Western'

# %%
model_3 = SM.logit(formula=f_3,data=data).fit()
model_3.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.473284
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:          Scholarship_1   No. Observations:                 4462
# Model:                          Logit   Df Residuals:                     4448
# Method:                           MLE   Df Model:                           13
# Date:                Sun, 07 Feb 2021   Pseudo R-squ.:                  0.2872
# Time:                        21:10:00   Log-Likelihood:                -2111.8
# converged:                       True   LL-Null:                       -2962.8
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
print('The adjusted pseudo R-square value is',1 - ((model_3.llf - model_3.df_model)/model_3.llnull))
# Out:
# The adjusted pseudo R-square value is 0.2828374003740155

# %% [markdown]
# #### Let's check multicollinearity using Variance Inflation Factor (VIF) for the predictor variables.

# %%
def vif_cal(input_data):
    x_vars=input_data
    xvar_names=input_data.columns
    for i in range(0,xvar_names.shape[0]):
        y=x_vars[xvar_names[i]] 
        x=x_vars[xvar_names.drop(xvar_names[i])]
        rsq=SM.ols(formula="y~x", data=x_vars).fit().rsquared  
        vif=round(1/(1-rsq),2)
        print (xvar_names[i], " VIF = " , vif)

# %%
vif_cal(input_data=data[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Low',
       'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_B', 'School_Type_C', 'School_Type_D', 'Region_Southern',
       'Region_Western']])
# Out:
# Academic_Score  VIF =  1.7
# Score_on_Plays_Made  VIF =  1.61
# Missed_Play_Score  VIF =  1.52
# School_Score  VIF =  1.3
# Overall_Score  VIF =  1.96
# Injury_Propensity_Low  VIF =  3.61
# Injury_Propensity_Moderate  VIF =  2.1
# Injury_Propensity_Normal  VIF =  2.67
# School_Type_B  VIF =  15.45
# School_Type_C  VIF =  14.15
# School_Type_D  VIF =  6.43
# Region_Southern  VIF =  1.23
# Region_Western  VIF =  1.26

# %% [markdown]
# #### Model 4

# %% [markdown]
# Deleting the variable which has the highest VIF - School_Type_B

# %%
f_4 = 'Scholarship_1~Academic_Score + Score_on_Plays_Made + Missed_Play_Score+School_Score + Overall_Score + Injury_Propensity_Low + Injury_Propensity_Moderate + Injury_Propensity_Normal + School_Type_C + School_Type_D + Region_Southern + Region_Western'

# %%
model_4 = SM.logit(formula=f_4,data=data).fit()
model_4.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.477047
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:          Scholarship_1   No. Observations:                 4462
# Model:                          Logit   Df Residuals:                     4449
# Method:                           MLE   Df Model:                           12
# Date:                Sun, 07 Feb 2021   Pseudo R-squ.:                  0.2816
# Time:                        21:10:20   Log-Likelihood:                -2128.6
# converged:                       True   LL-Null:                       -2962.8
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
print('The adjusted pseudo R-square value is',1 - ((model_4.llf - model_4.df_model)/model_4.llnull))
# Out:
# The adjusted pseudo R-square value is 0.27750807669713196

# %% [markdown]
# We see that the adjusted pseudo R-square value of the model has decreased. We have dropped a variable due to Multicollinearity (and not because of significance)

# %%
vif_cal(input_data=data[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Low',
       'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern',
       'Region_Western']])
# Out:
# Academic_Score  VIF =  1.53
# Score_on_Plays_Made  VIF =  1.56
# Missed_Play_Score  VIF =  1.52
# School_Score  VIF =  1.25
# Overall_Score  VIF =  1.69
# Injury_Propensity_Low  VIF =  3.11
# Injury_Propensity_Moderate  VIF =  2.01
# Injury_Propensity_Normal  VIF =  2.51
# School_Type_C  VIF =  2.13
# School_Type_D  VIF =  2.54
# Region_Southern  VIF =  1.23
# Region_Western  VIF =  1.26

# %% [markdown]
# #### Model 5

# %% [markdown]
# Deleting the variable which has the highest VIF - Injury_Propensity_Low

# %%
f_5 = 'Scholarship_1~Academic_Score + Score_on_Plays_Made + Missed_Play_Score+School_Score + Overall_Score + Injury_Propensity_Moderate + Injury_Propensity_Normal + School_Type_C + School_Type_D + Region_Southern + Region_Western'

# %%
model_5 = SM.logit(formula=f_5,data=data).fit()
model_5.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.484761
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:          Scholarship_1   No. Observations:                 4462
# Model:                          Logit   Df Residuals:                     4450
# Method:                           MLE   Df Model:                           11
# Date:                Sun, 07 Feb 2021   Pseudo R-squ.:                  0.2699
# Time:                        21:10:21   Log-Likelihood:                -2163.0
# converged:                       True   LL-Null:                       -2962.8
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
print('The adjusted pseudo R-square value is',1 - ((model_5.llf - model_5.df_model)/model_5.llnull))
# Out:
# The adjusted pseudo R-square value is 0.266227966543902

# %%
vif_cal(input_data=data[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern','Region_Western']])
# Out:
# Academic_Score  VIF =  1.46
# Score_on_Plays_Made  VIF =  1.55
# Missed_Play_Score  VIF =  1.49
# School_Score  VIF =  1.2
# Overall_Score  VIF =  1.68
# Injury_Propensity_Moderate  VIF =  1.18
# Injury_Propensity_Normal  VIF =  1.1
# School_Type_C  VIF =  2.05
# School_Type_D  VIF =  2.1
# Region_Southern  VIF =  1.23
# Region_Western  VIF =  1.25

# %% [markdown]
# #### Model 6

# %% [markdown]
# VIF indicates there is no Multicollinearity problem.
#
# Based on 'p value', let's drop Region_Western because it is not significant

# %%
f_6 = 'Scholarship_1~Academic_Score + Score_on_Plays_Made + Missed_Play_Score+School_Score + Overall_Score + Injury_Propensity_Moderate + Injury_Propensity_Normal + School_Type_C + School_Type_D + Region_Southern'

# %%
model_6 = SM.logit(formula=f_6,data=data).fit()
model_6.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.484795
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:          Scholarship_1   No. Observations:                 4462
# Model:                          Logit   Df Residuals:                     4451
# Method:                           MLE   Df Model:                           10
# Date:                Sun, 07 Feb 2021   Pseudo R-squ.:                  0.2699
# Time:                        21:10:41   Log-Likelihood:                -2163.2
# converged:                       True   LL-Null:                       -2962.8
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
print('The adjusted pseudo R-square value is',1 - ((model_6.llf - model_6.df_model)/model_6.llnull))
# Out:
# The adjusted pseudo R-square value is 0.26651442016778726

# %%
vif_cal(input_data=data[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern']])
# Out:
# Academic_Score  VIF =  1.46
# Score_on_Plays_Made  VIF =  1.5
# Missed_Play_Score  VIF =  1.49
# School_Score  VIF =  1.2
# Overall_Score  VIF =  1.68
# Injury_Propensity_Moderate  VIF =  1.18
# Injury_Propensity_Normal  VIF =  1.1
# School_Type_C  VIF =  2.03
# School_Type_D  VIF =  2.1
# Region_Southern  VIF =  1.09

# %% [markdown]
# #### Model 7

# %% [markdown]
# Based on 'p value', drop Injury_Propensity_Normal

# %%
f_7 = 'Scholarship_1~Academic_Score + Score_on_Plays_Made + Missed_Play_Score+School_Score + Overall_Score + Injury_Propensity_Moderate + School_Type_C + School_Type_D + Region_Southern'

# %%
model_7 = SM.logit(formula=f_7,data=data).fit()
model_7.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.484823
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:          Scholarship_1   No. Observations:                 4462
# Model:                          Logit   Df Residuals:                     4452
# Method:                           MLE   Df Model:                            9
# Date:                Sun, 07 Feb 2021   Pseudo R-squ.:                  0.2698
# Time:                        21:10:53   Log-Likelihood:                -2163.3
# converged:                       True   LL-Null:                       -2962.8
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
print('The adjusted pseudo R-square value is',1 - ((model_7.llf - model_7.df_model)/model_7.llnull))
# Out:
# The adjusted pseudo R-square value is 0.266810445108563

# %%
vif_cal(input_data=data[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate',
       'School_Type_C', 'School_Type_D', 'Region_Southern']])
# Out:
# Academic_Score  VIF =  1.45
# Score_on_Plays_Made  VIF =  1.49
# Missed_Play_Score  VIF =  1.49
# School_Score  VIF =  1.2
# Overall_Score  VIF =  1.66
# Injury_Propensity_Moderate  VIF =  1.13
# School_Type_C  VIF =  2.02
# School_Type_D  VIF =  2.1
# Region_Southern  VIF =  1.08

# %% [markdown]
# ## Prediction on the Data

# %% [raw]
# Now, let us see the predicted probability values.
#
# There are probabilities of an individual going to Default

# %%
y_prob_pred_7 = model_7.predict()
y_prob_pred_7
# Out:
# array([0.21957402, 0.35593307, 0.25485555, ..., 0.78040409, 0.81675883,
#        0.8437596 ])

# %%
y_class_pred=(y_prob_pred_7>=0.5).astype(np.int)
y_class_pred
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %% [markdown]
# # Model Evaluation on the Data

# %% [raw]
# Let us now check the confusion matrix and the classification report followed by the AUC and the AUC-ROC curve.

# %%
from sklearn import metrics

# %%
sns.heatmap((metrics.confusion_matrix(data['Scholarship_1'],y_class_pred)),annot=True,fmt='.5g'
            ,cmap='Greys');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

# %%
tn, fp, fn, tp = metrics.confusion_matrix(data['Scholarship_1'],y_class_pred).ravel()
print('True Negative:',tn,'\n''False Positives:' ,fp,'\n''False Negatives:', fn,'\n''True Positives:', tp)
# Out:
# True Negative: 2544
# False Positives: 223
# False Negatives: 637
# True Positives: 1058

# %% [raw]
# Let us now go ahead and print the classification report to check the various other parameters.

# %%
print(metrics.classification_report(data['Scholarship_1'],y_class_pred,digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.800     0.919     0.855      2767
#            1      0.826     0.624     0.711      1695
#
#     accuracy                          0.807      4462
#    macro avg      0.813     0.772     0.783      4462
# weighted avg      0.810     0.807     0.801      4462

# %%
metrics.accuracy_score(data['Scholarship_1'],y_class_pred)
# Out:
# 0.8072613177947109

# %%
for j in np.arange(0.1,1,0.1):
    custom_prob = j #defining the cut-off value of our choice
    y_class_pred_custom_cutoff=(y_prob_pred_7>=custom_prob).astype(np.int)
    y_class_pred_custom_cutoff
   
    print(round(j,3),metrics.accuracy_score(data['Scholarship_1'],y_class_pred_custom_cutoff))
# Out:
# 0.1 0.43881667413715825
# 0.2 0.6015239802779023
# 0.3 0.7115643209323174
# 0.4 0.7767817122366651
# 0.5 0.8072613177947109
# 0.6 0.8142088749439713
# 0.7 0.8003137606454505
# 0.8 0.763334827431645
# 0.9 0.6777229941730166

# %% [raw]
# Now we will use a different cut-off value to predict the classes and build the confusion matrix and classification report.

# %%
cut_off = 0.6
y_class_pred_custom_cutoff=(y_prob_pred_7 >= cut_off).astype(np.int)
y_class_pred_custom_cutoff
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
sns.heatmap((metrics.confusion_matrix(data['Scholarship_1'],y_class_pred_custom_cutoff)),annot=True,fmt='.5g'
            ,cmap='Greys');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

tn, fp, fn, tp = metrics.confusion_matrix(data['Scholarship_1'],y_class_pred_custom_cutoff).ravel()
print('True Negative:',tn,'\n''False Positives:' ,fp,'\n''False Negatives:', fn,'\n''True Positives:', tp)

print(metrics.classification_report(data['Scholarship_1'],y_class_pred_custom_cutoff,digits=3))
# Out:
# True Negative: 2673
# False Positives: 94
# False Negatives: 735
# True Positives: 960
#               precision    recall  f1-score   support
#
#            0      0.784     0.966     0.866      2767
#            1      0.911     0.566     0.698      1695
#
#     accuracy                          0.814      4462
#    macro avg      0.848     0.766     0.782      4462
# weighted avg      0.832     0.814     0.802      4462

# %% [markdown]
# # Only for Predictive purposes of Logistic Regression

# %%
from sklearn.model_selection import train_test_split

# %%
Train,Test = train_test_split(data,test_size=0.3,random_state=10,stratify=data['Scholarship_1'])

# %% [raw]
# Checking the proportion of 1s and 0s in the target variable in both Training and Test data.

# %%
print(Train['Scholarship_1'].value_counts(1),'\n')
print(Test['Scholarship_1'].value_counts(1))
# Out:
# 0    0.620237
# 1    0.379763
# Name: Scholarship_1, dtype: float64
#
# 0    0.619866
# 1    0.380134
# Name: Scholarship_1, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(penalty='none',solver='newton-cg')

# %% [markdown]
# ### Using only the Model 4 variables to build the model on the training data and predict on the training as well as test data.

# %%
model_sklearn_4 = lr.fit(Train[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Low',
       'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern',
       'Region_Western']],Train['Scholarship_1'])

# %%
# Predicting on the Training Data

model_sklearn_4_pred_train = model_sklearn_4.predict(Train[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Low',
       'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern','Region_Western']])

# %%
# Predicting on the Test Data

model_sklearn_4_pred_test = model_sklearn_4.predict(Test[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Low',
       'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern','Region_Western']])

# %%
# Get probability values
model_sklearn_4_test_proba = model_sklearn_4.predict_proba(Test[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Low',
       'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern','Region_Western']])

# %% [markdown]
# ### Using only the Model 5 variables to build the model on the training data and predict on the training as well as test data.

# %%
model_sklearn_5 = lr.fit(Train[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score','Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern','Region_Western']],Train['Scholarship_1'])

# %%
# Predicting on the Training Data

model_sklearn_5_pred_train = model_sklearn_4.predict(Train[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern','Region_Western']])

# %%
# Predicting on the Test Data

model_sklearn_5_pred_test = model_sklearn_4.predict(Test[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern','Region_Western']])

# %%
# Get probability values
model_sklearn_5_test_proba = model_sklearn_4.predict_proba(Test[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern','Region_Western']])

# %% [markdown]
# ### Using only the Model 6 variables to build the model on the training data and predict on the training as well as test data.

# %%
model_sklearn_6 = lr.fit(Train[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score','Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern',]],Train['Scholarship_1'])

# %%
# Predicting on the Training Data

model_sklearn_6_pred_train = model_sklearn_6.predict(Train[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern',]])

# %%
# Predicting on the Test Data

model_sklearn_6_pred_test = model_sklearn_6.predict(Test[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern',]])

# %%
# Get probability values
model_sklearn_6_test_proba = model_sklearn_6.predict_proba(Test[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern',]])

# %% [markdown]
# ### Using only the Model 7 variables to build the model on the training data and predict on the training as well as test data.

# %%
model_sklearn_7 = lr.fit(Train[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate',
       'School_Type_C', 'School_Type_D', 'Region_Southern']],Train['Scholarship_1'])

# %%
# Predicting on the Training Data

model_sklearn_7_pred_train = model_sklearn_7.predict(Train[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate',
       'School_Type_C', 'School_Type_D', 'Region_Southern']])

# %%
# Predicting on the Test Data

model_sklearn_7_pred_test = model_sklearn_7.predict(Test[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate',
       'School_Type_C', 'School_Type_D', 'Region_Southern']])

# %%
# Get probability values
model_sklearn_7_test_proba = model_sklearn_7.predict_proba(Test[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate',
       'School_Type_C', 'School_Type_D', 'Region_Southern']])

# %% [markdown]
# ## Confusion Matrix check for all the models built

# %%
from sklearn import metrics

# %%
sns.heatmap((metrics.confusion_matrix(Train['Scholarship_1'],model_sklearn_4_pred_train)),annot=True,fmt='.5g'
            ,cmap='Greys');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

# %%
sns.heatmap((metrics.confusion_matrix(Train['Scholarship_1'],model_sklearn_5_pred_train)),annot=True,fmt='.5g'
            ,cmap='Greys');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

# %%
sns.heatmap((metrics.confusion_matrix(Train['Scholarship_1'],model_sklearn_6_pred_train)),annot=True,fmt='.5g'
            ,cmap='Greys');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

# %%
sns.heatmap((metrics.confusion_matrix(Train['Scholarship_1'],model_sklearn_7_pred_train)),annot=True,fmt='.5g'
            ,cmap='Greys');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

# %%
print('Accuracy Score - Model 4')
print('Training:', metrics.accuracy_score(Train['Scholarship_1'],model_sklearn_4_pred_train))
print('Testing: ', metrics.accuracy_score(Test['Scholarship_1'],model_sklearn_4_pred_test))

print('\nAccuracy Score - Model 5')
print('Training:', metrics.accuracy_score(Train['Scholarship_1'],model_sklearn_5_pred_train))
print('Testing: ', metrics.accuracy_score(Test['Scholarship_1'],model_sklearn_5_pred_test))

print('\nAccuracy Score - Model 6')
print('Training:', metrics.accuracy_score(Train['Scholarship_1'],model_sklearn_6_pred_train))
print('Testing: ', metrics.accuracy_score(Test['Scholarship_1'],model_sklearn_6_pred_test))

print('\nAccuracy Score - Model 7')
print('Training:', metrics.accuracy_score(Train['Scholarship_1'],model_sklearn_7_pred_train))
print('Testing: ', metrics.accuracy_score(Test['Scholarship_1'],model_sklearn_7_pred_test))
# Out:
# Accuracy Score - Model 4
# Training: 0.8178033941722702
# Testing:  0.7953696788648245
#
# Accuracy Score - Model 5
# Training: 0.8097982708933718
# Testing:  0.79462285287528
#
# Accuracy Score - Model 6
# Training: 0.8101184758245277
# Testing:  0.79462285287528
#
# Accuracy Score - Model 7
# Training: 0.8091578610310599
# Testing:  0.7961165048543689

# %% [markdown]
# ### Following is additional tuning based on changing cut-off values (using chosen Model 7)

# %%
# View the preictions
model_sklearn_7_pred_test
# Out:
# array([0, 1, 0, ..., 1, 0, 1], dtype=uint8)

# %%
# View the probabilities estimated
# the first column shows probability of NotDefault and the second column shows the Probability of YesDefault
model_sklearn_7_test_proba
# Out:
# array([[0.64108674, 0.35891326],
#        [0.11578153, 0.88421847],
#        [0.87618965, 0.12381035],
#        ...,
#        [0.07141358, 0.92858642],
#        [0.79331419, 0.20668581],
#        [0.13288233, 0.86711767]])

# %%
# Following will enable to extract only the probability of YesDefault
model_sklearn_7_test_proba[:,1]
# Out:
# array([0.35891326, 0.88421847, 0.12381035, ..., 0.92858642, 0.20668581,
#        0.86711767])

# %%
# AUC and ROC for the training data


# calculating on the basis of a person not defaulting
# calculate AUC
auc = metrics.roc_auc_score(Test['Scholarship_1'],model_sklearn_7_test_proba[:,1])
print('AUC: %.3f' % auc)
# # calculate roc curve
# from sklearn.metrics import roc_curve
fpr, tpr, thresholds = metrics.roc_curve(Test['Scholarship_1'],model_sklearn_7_test_proba[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# AUC: 0.793

# %% [markdown]
# #### LDA

# %%
#Building the Discriminant Model
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
LDA = LinearDiscriminantAnalysis()

# %% [markdown]
# #### Model 1 - Building the LDA model on the Training Data and checking the Accuracy score on the training data.

# %%
model_1_LDA = LDA.fit(Train[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score','School_Score', 'Overall_Score', 'Injury_Propensity_Low','Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_B','School_Type_C', 'School_Type_D', 'Region_Southern','Region_Western']],Train['Scholarship_1'])

# %%
print('Accuracy Score of LDA Model 1:',model_1_LDA.score(Train[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score','School_Score', 'Overall_Score', 'Injury_Propensity_Low','Injury_Propensity_Moderate','Injury_Propensity_Normal','School_Type_B','School_Type_C', 'School_Type_D', 'Region_Southern','Region_Western']],Train['Scholarship_1']))
# Out:
# Accuracy Score of LDA Model 1: 0.8251681075888568

# %%
# Model 1 - Predicting the classes and the probabilities on the Test Data for the LDA model

# %%
model_1_LDA_test_class = model_1_LDA.predict(Test[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score','School_Score', 'Overall_Score', 'Injury_Propensity_Low','Injury_Propensity_Moderate','Injury_Propensity_Normal','School_Type_B','School_Type_C', 'School_Type_D', 'Region_Southern','Region_Western']])
model_1_LDA_test_probabilities = model_1_LDA.predict_proba(Test[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score','School_Score', 'Overall_Score', 'Injury_Propensity_Low','Injury_Propensity_Moderate','Injury_Propensity_Normal','School_Type_B','School_Type_C', 'School_Type_D', 'Region_Southern','Region_Western']])

# %% [markdown]
# #### Model 2 - Building the LDA model on the Training Data and checking the Accuracy score on the training data.

# %%
model_2_LDA = LDA.fit(Train[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Low',
       'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern',
       'Region_Western']],Train['Scholarship_1'])

# %%
print('Accuracy Score of LDA Model 2:',model_2_LDA.score(Train[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Low',
       'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern',
       'Region_Western']],Train['Scholarship_1']))
# Out:
# Accuracy Score of LDA Model 2: 0.8222862632084534

# %%
# Model 2 - Predicting the classes and the probabilities on the Test Data for the LDA model

# %%
model_2_LDA_test_class = model_2_LDA.predict(Test[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Low',
       'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern',
       'Region_Western']])
model_2_LDA_test_probabilities = model_2_LDA.predict_proba(Test[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Low',
       'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern',
       'Region_Western']])

# %% [markdown]
# #### Model 3 - Building the LDA model on the Training Data and checking the Accuracy score on the training data.

# %%
model_3_LDA = LDA.fit(Train[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern','Region_Western']],Train['Scholarship_1'])

# %%
print('Accuracy Score of LDA Model 3:',model_3_LDA.score(Train[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern','Region_Western']],Train['Scholarship_1']))
# Out:
# Accuracy Score of LDA Model 3: 0.8126801152737753

# %%
# Model 3 - Predicting the classes and the probabilities on the Test Data for the LDA model

# %%
model_3_LDA_test_class = model_3_LDA.predict(Test[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern','Region_Western']])
model_3_LDA_test_probabilities = model_3_LDA.predict_proba(Test[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern','Region_Western']])

# %% [markdown]
# #### Model 4 - Building the LDA model on the Training Data and checking the Accuracy score on the training data.

# %%
model_4_LDA = LDA.fit(Train[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern']],Train['Scholarship_1'])

# %%
print('Accuracy Score of LDA Model 4:',model_4_LDA.score(Train[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern']],Train['Scholarship_1']))
# Out:
# Accuracy Score of LDA Model 4: 0.8133205251360871

# %%
# Model 4 - Predicting the classes and the probabilities on the Test Data for the LDA model

# %%
model_4_LDA_test_class = model_4_LDA.predict(Test[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern']])
model_4_LDA_test_probabilities = model_4_LDA.predict_proba(Test[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate', 'Injury_Propensity_Normal',
       'School_Type_C', 'School_Type_D', 'Region_Southern']])

# %% [markdown]
# #### Model 5 - Building the LDA model on the Training Data and checking the Accuracy score on the training data.

# %%
model_5_LDA = LDA.fit(Train[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate',
       'School_Type_C', 'School_Type_D', 'Region_Southern']],Train['Scholarship_1'])

# %%
print('Accuracy Score of LDA Model 5:',model_5_LDA.score(Train[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate',
       'School_Type_C', 'School_Type_D', 'Region_Southern']],Train['Scholarship_1']))
# Out:
# Accuracy Score of LDA Model 5: 0.8113992955491515

# %%
# Model 5 - Predicting the classes and the probabilities on the Test Data for the LDA model

# %%
model_5_LDA_test_class = model_5_LDA.predict(Test[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate',
       'School_Type_C', 'School_Type_D', 'Region_Southern']])
model_5_LDA_test_probabilities = model_5_LDA.predict_proba(Test[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate',
       'School_Type_C', 'School_Type_D', 'Region_Southern']])

# %%
model_5_LDA_train_class = model_5_LDA.predict(Train[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate',
       'School_Type_C', 'School_Type_D', 'Region_Southern']])
model_5_LDA_train_probabilities = model_5_LDA.predict_proba(Train[['Academic_Score', 'Score_on_Plays_Made', 'Missed_Play_Score',
       'School_Score', 'Overall_Score', 'Injury_Propensity_Moderate',
       'School_Type_C', 'School_Type_D', 'Region_Southern']])

# %% [markdown]
# #### Evaluate the LDA models on the test data using the various statistics of the confusion matrix and the AUC-ROC curve.

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 15,4

# %%
f,a =  plt.subplots(1,5,sharex=True,sharey=True,squeeze=False)

#Plotting confusion matrix for the different models for the Training Data

plot_0 = sns.heatmap((metrics.confusion_matrix(Test['Scholarship_1'],model_1_LDA_test_class)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][0]);
a[0][0].set_title('LDA Model_1')

plot_1 = sns.heatmap((metrics.confusion_matrix(Test['Scholarship_1'],model_2_LDA_test_class)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][1]);
a[0][1].set_title('LDA Model 2');

plot_1 = sns.heatmap((metrics.confusion_matrix(Test['Scholarship_1'],model_3_LDA_test_class)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][2]);
a[0][2].set_title('LDA Model 3');

plot_1 = sns.heatmap((metrics.confusion_matrix(Test['Scholarship_1'],model_4_LDA_test_class)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][3]);
a[0][3].set_title('LDA Model 4');

plot_1 = sns.heatmap((metrics.confusion_matrix(Test['Scholarship_1'],model_5_LDA_test_class)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][4]);
a[0][4].set_title('LDA Model 5');

# %%
print('LDA Model 1')
tn, fp, fn, tp = metrics.confusion_matrix(Test['Scholarship_1'],model_1_LDA_test_class).ravel()
print('True Negative:',tn,'\n''False Positives:' ,fp,'\n''False Negatives:', fn,'\n''True Positives:', tp,'\n\n')

print('LDA Model 2')
tn, fp, fn, tp = metrics.confusion_matrix(Test['Scholarship_1'],model_2_LDA_test_class).ravel()
print('True Negative:',tn,'\n''False Positives:' ,fp,'\n''False Negatives:', fn,'\n''True Positives:', tp,'\n\n')

print('LDA Model 3')
tn, fp, fn, tp = metrics.confusion_matrix(Test['Scholarship_1'],model_3_LDA_test_class).ravel()
print('True Negative:',tn,'\n''False Positives:' ,fp,'\n''False Negatives:', fn,'\n''True Positives:', tp,'\n\n')

print('LDA Model 4')
tn, fp, fn, tp = metrics.confusion_matrix(Test['Scholarship_1'],model_4_LDA_test_class).ravel()
print('True Negative:',tn,'\n''False Positives:' ,fp,'\n''False Negatives:', fn,'\n''True Positives:', tp,'\n\n')

print('LDA Model 5')
tn, fp, fn, tp = metrics.confusion_matrix(Test['Scholarship_1'],model_5_LDA_test_class).ravel()
print('True Negative:',tn,'\n''False Positives:' ,fp,'\n''False Negatives:', fn,'\n''True Positives:', tp)
# Out:
# LDA Model 1
# True Negative: 762
# False Positives: 68
# False Negatives: 194
# True Positives: 315
#
#
# LDA Model 2
# True Negative: 761
# False Positives: 69
# False Negatives: 202
# True Positives: 307
#
#
# LDA Model 3
# True Negative: 767
# False Positives: 63
# False Negatives: 203
# True Positives: 306
#
#
# LDA Model 4
# True Negative: 767
# False Positives: 63
# False Negatives: 204
# True Positives: 305
#
#
# LDA Model 5
# True Negative: 766
# False Positives: 64
# False Negatives: 201
# True Positives: 308

# %%
print('LDA Model 1')
print(metrics.classification_report(Test['Scholarship_1'],model_1_LDA_test_class),'\n')

print('LDA Model 2')
print(metrics.classification_report(Test['Scholarship_1'],model_2_LDA_test_class),'\n')

print('LDA Model 3')
print(metrics.classification_report(Test['Scholarship_1'],model_3_LDA_test_class))

print('LDA Model 4')
print(metrics.classification_report(Test['Scholarship_1'],model_4_LDA_test_class),'\n')

print('LDA Model 5')
print(metrics.classification_report(Test['Scholarship_1'],model_5_LDA_test_class))
# Out:
# LDA Model 1
#               precision    recall  f1-score   support
#
#            0       0.80      0.92      0.85       830
#            1       0.82      0.62      0.71       509
#
#     accuracy                           0.80      1339
#    macro avg       0.81      0.77      0.78      1339
# weighted avg       0.81      0.80      0.80      1339
#
#
# LDA Model 2
#               precision    recall  f1-score   support
#
#            0       0.79      0.92      0.85       830
#            1       0.82      0.60      0.69       509
#
#     accuracy                           0.80      1339
#    macro avg       0.80      0.76      0.77      1339
# weighted avg       0.80      0.80      0.79      1339
#
#
# LDA Model 3
#               precision    recall  f1-score   support
#
#            0       0.79      0.92      0.85       830
#            1       0.83      0.60      0.70       509
#
#     accuracy                           0.80      1339
# ...

# %% [markdown]
# ### Selected Model - 7

# %% [markdown]
# #### Logistic Regression

# %%
print('Training:', metrics.accuracy_score(Train['Scholarship_1'],model_sklearn_7_pred_train))
print('Testing: ', metrics.accuracy_score(Test['Scholarship_1'],model_sklearn_7_pred_test))
# Out:
# Training: 0.8091578610310599
# Testing:  0.7961165048543689

# %%
print(metrics.classification_report(data['Scholarship_1'],y_class_pred,digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.800     0.919     0.855      2767
#            1      0.826     0.624     0.711      1695
#
#     accuracy                          0.807      4462
#    macro avg      0.813     0.772     0.783      4462
# weighted avg      0.810     0.807     0.801      4462

# %% [markdown]
# #### LDA

# %%
print('Training: ', metrics.accuracy_score(Train['Scholarship_1'],model_5_LDA_train_class))
print('Testing: ', metrics.accuracy_score(Test['Scholarship_1'],model_5_LDA_test_class))
# Out:
# Training:  0.8113992955491515
# Testing:  0.8020911127707244

# %%
print(metrics.classification_report(Test['Scholarship_1'],model_5_LDA_test_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.92      0.85       830
#            1       0.83      0.61      0.70       509
#
#     accuracy                           0.80      1339
#    macro avg       0.81      0.76      0.78      1339
# weighted avg       0.81      0.80      0.79      1339
